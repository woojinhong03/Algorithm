# %%
n = int(input())
ans = 0

for _ in range(n):
    stack = []
    dan = input()

    for i in dan:
        if stack and stack[-1] == i:
            stack.pop()
        else:
            stack.append(i)

    if not stack:
        ans += 1

print(ans)
# Out:
# 3
# ABAB
# AABB
# ABBA
# 2
