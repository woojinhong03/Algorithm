# %%
import sys
input = sys.stdin.readline

n = int(input())
arr = [int(input()) for _ in range(n)]

cnt = top = 0

for i in reversed(arr):
    if top < i:
        cnt += 1
        top = i

print(cnt)
# Out:
# 6
# 6
# 9
# 7
# 6
# 4
# 6
# 3
